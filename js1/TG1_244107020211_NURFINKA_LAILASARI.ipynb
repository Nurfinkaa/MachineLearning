# %% [markdown]
# <a href="https://colab.research.google.com/github/Nurfinkaa/MachineLearning/blob/main/js1/TG1_244107020211_NURFINKA_LAILASARI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tugas Praktikum 1**
# ---

# %%
# !pip install mne

# %% [markdown]
# ---
#
# ## **Bagian 1**
# ---

# %%
import os
os.environ["SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL"] = "True"

# !pip install pyprep scipy wandb --quiet
# !pip install pyecg --no-deps --quiet
# !pip install ishneholterlib pythoncrc wfdb --quiet

# %%
import pyprep
print("pyprep version:", pyprep.__version__)
# Out:
# pyprep version: 0.9.0

# %%
import scipy
print("scipy version:", scipy.__version__)
# Out:
# scipy version: 1.16.3

# %%
import wandb
print("wandb version:", wandb.__version__)
# Out:
# wandb version: 0.28.1

# %%
import pyecg
print("pyECG (pyecg) berhasil diimpor")
# Out:
# /usr/local/lib/python3.13/dist-packages/pyecg/__init__.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# pyECG (pyecg) berhasil diimpor

# %% [markdown]
# ---
#
#
# **Jelaskan kegunakan masing-masing library tersebut.**
#
#
# ---

# %% [markdown]
# 1. **PyPREP** : digunakan untuk membersihkan data sinyal EEG. Library
# ini membantu mengurangi gangguan pada data dan memperbaiki bagian data yang bermasalah. Jadi, data EEG menjadi lebih bersih dan siap digunakan untuk analisis.
#
# 2. **SciPy** : digunakan untuk mengolah dan menghitung data. Library ini menyediakan berbagai fungsi untuk matematika, statistik, dan pengolahan sinyal. Jadi, SciPy bisa membantu dalam proses perhitungan dan pengolahan data.
#
# 3. **wandb (Weights & Biases)** : digunakan untuk mencatat hasil percobaan machine learning. Contohnya, kita bisa menyimpan nilai accuracy dan loss dari model. Hasil dari beberapa percobaan juga bisa dibandingkan dengan lebih mudah.
#
# 4. **pyECG** : digunakan untuk membaca dan mengolah data ECG/EKG. ECG adalah data yang menunjukkan aktivitas listrik pada jantung. Dengan library ini, data ECG bisa dibaca dan kemudian digunakan untuk proses seperti analisis atau pembuatan model machine learning.

# %% [markdown]
# ---
# ## **Bagian 2**
# ---

# %% [markdown]
# 1.  Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.

# %% [markdown]
# > Salah satu contoh yang paling sering kejadian sekarang ini adalah penyalahgunaan AI buat bikin gambar atau video palsu (deepfake), termasuk yang isinya konten pornografi palsu pakai wajah orang lain tanpa izin. Ini pernah kejadian di beberapa kampus di Indonesia, salah satunya di Universitas Udayana, dan juga banyak kasus serupa di luar negeri.
#
# > Ini jelas melanggar etika karena pakai wajah/data pribadi orang tanpa persetujuan, bisa ngerusak nama baik dan martabat korbannya. Dari sisi hukum di Indonesia, ini bisa kena:
# * UU PDP (No. 27/2022) — karena wajah termasuk data biometrik yang dilindungi.
# * UU ITE (No. 11/2008 jo. No. 19/2016) — soal penyebaran konten yang melanggar kesusilaan.
# * SE Kemenkominfo No. 9/2023 tentang Etika AI — yang bilang pemakaian * AI harus tetap perhatiin prinsip etis dan kehati-hatian.
#
# >Referensi:
#
# * Fakultas Hukum UII (2024). Upaya Penegakan Etika Hukum Terhadap * * * Teknologi AI Content Generated. law.uii.ac.id.
# * Mahasiswa Indonesia (2025). Kecerdasan Buatan Melesat, Hukum Tak * * Kunjung Pesat. mahasiswaindonesia.id.

# %% [markdown]
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.

# %% [markdown]
# > AI, terutama yang tipe generatif (kayak ChatGPT, dll), butuh komputer super banyak buat "belajar" dan jalan terus-menerus. Semua itu jalan di data center, dan data center ini makan listrik gede banget — belum lagi butuh air buat pendinginan servernya. Menurut IEA, konsumsi listrik data center dunia diperkirakan naik dua kali lipat, bisa nyampe hampir 1.000 TWh di 2026-2030, setara pemakaian listrik satu negara kayak Jepang. Di Indonesia sendiri, kebutuhan listrik data center diperkirakan naik hampir 5x lipat dari 2025 ke 2034, dan sayangnya sumber listriknya masih banyak dari batu bara, jadi emisi karbonnya juga ikut naik.
#
# > Pendapat aku soal cara ngatasinnya :
#  Bikin model AI yang lebih hemat — nggak semua tugas butuh model raksasa, model yang lebih kecil/efisien bisa dipakai buat hal-hal yang nggak terlalu berat.
# Pindah ke energi terbarukan — data center dorong pakai listrik dari matahari/angin, bukan cuma dari batu bara.
# Manfaatin AI buat hemat energi juga — ironisnya AI bisa dipakai buat ngatur pendinginan dan listrik data center biar lebih efisien.
# Ada aturan dari pemerintah — biar perusahaan wajib lapor jejak karbon mereka, jadi ada kontrol dan transparansi.
#
# > Referensi:
# * IEA, dikutip di Katadata Green (2024). Bisakah Iklim Bertahan dari Gempuran Permintaan Energi Data Center AI?
# * Teknik Elektro ITI (2025). Ledakan Kebutuhan Energi Pusat Data AI.
# * FTMM Unair (2025). AI Katanya Cerdas, Kok Bikin Bumi Makin Panas?
